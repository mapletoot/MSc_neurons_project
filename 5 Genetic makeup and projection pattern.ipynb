# %% [markdown]
# # Clusters and Supertype probabilities

# %%
# Import packages for data manipulation and visualization
import pandas as pd
import anndata as ad
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# For searching supertypes and importing classifiers
import re
import joblib

# Extra libraries for pipelines, transformers etc
from sklearn.preprocessing import StandardScaler # scaling features
from sklearn.preprocessing import Normalizer
from sklearn.pipeline import make_pipeline  
from sklearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer

# For the mixture models
from sklearn.mixture import GaussianMixture

#  For chi squred test
from scipy.stats import chi2_contingency

# Import packages for neuron visualizations
from brainrender import Scene
from brainrender.actors import Points
import vedo
vedo.settings.default_backend= 'vtk'

# %% [markdown]
# # Import data and get it ready for plotting with filtering

# %%
# load EC data (imputed MERFISH) object
source = "Data/ec_obj_imputed_log2.h5ad"
ec_data = ad.read_h5ad(source)

# Load in the metadata to get access to location, sructure(region) and classes (inc subclasses and supertypes)
cell_metadata = ec_data.obs

# Load SNR data for visualisations on Brain Render
ec_snr_data = pd.read_csv('Data/ec_snr_data_with_clusters.csv')

# access the lengthn and count columns
length_cols = [col for col in ec_snr_data if col.endswith("_length")]
count_cols = [col for col in ec_snr_data if col.endswith("_endpoint")]

# Import best model from the SNR clustering classifier
best_svm_cluster = joblib.load("Models/best_cluster_classifier.pkl")
best_svm_supertype = joblib.load("Models/best_svm_4supertypes.pkl")
snr_classes = best_svm_cluster.classes_
supertype_classes = best_svm_supertype.classes_

# %%
# Make sure that the tables display the clusters in the same order as they have been doing throughout
label_map = ({
    0:'long_xlong_STRd_STRv_AI^ORB~very_lateral',
    1:'med_short_RSP_VIS^RSP~very_medial',
    2:'med_xlong_RSP_VIS_STR^blend~medial',
    3:'short_HIP_SUB^RSP~very_medial',
    4:'med_RSP_VIS_TEa^blend~medial',
    5:'med_AMY_STRv_STRd^ORB~very_lateral',
    6:'xshort_mixed^none~medial'
})

# The above helps us come up with a sensible ordering for the clusters from medial to lateral, and then placing the two mixed groups with bad tracing at the bottom
# Desired medial to lateral order with the two mixed groups, 4 & 6, at the end
cluster_label_order = [3, 1, 2, 5, 0, 4, 6]
cluster_order = [label_map[i] for i in cluster_label_order]

profile_display = profile_display.reindex(columns=cluster_order)

# %%
# Decide which locations and which supertypes to filter for
# Filters for supertypes:
all_supertypes = cell_metadata["supertype"].astype(str).unique()

non_gaba_supertypes = [
    s for s in all_supertypes
    if "gaba" not in s.lower()
]

layer5_supertypes = [
    s for s in non_gaba_supertypes
    if re.search(r"\bL5\b|\bL5/6\b|\bL4/5\b", s)
]

no_layer_supertypes = [
    s for s in non_gaba_supertypes
    if not re.search(r"\bL\d", s)
]

directed_supertypes = ['0129 NP PPP Glut_1','0007 L5/6 IT TPE-ENT Glut_1','0010 L5/6 IT TPE-ENT Glut_4','0008 L5/6 IT TPE-ENT Glut_2']


# location_filter = ["ENTm5", "ENTl5", "ENTl6a","ENTm6"]
supertype_filter = directed_supertypes

# %%
# Filter for chosen locations and chosen classes

# cell_metadata = cell_metadata.loc[cell_metadata['substructure'].isin(location_filter)]
cell_metadata = cell_metadata.loc[cell_metadata['supertype'].isin(supertype_filter)]

# Create an (x,y,z) object to classify each Merfish point into one of the clusters found previously
X_merfish = cell_metadata[['x_ccf','y_ccf','z_ccf']]
X_merfish = X_merfish.rename(columns = {'x_ccf':'x','y_ccf':'y','z_ccf':'z'})
print(X_merfish.columns)
X_merfish_mirror = X_merfish.copy()

# Separating points on left and right side of brain as classifier only works on 
right_mask = X_merfish["z"] < 5700
left_mask = X_merfish["z"] > 5700
X_merfish_mirror.loc[right_mask, "z"] = (
    2 * 5700 - X_merfish_mirror.loc[right_mask, "z"]
)
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %% [markdown]
# # Apply SNR classifier to filtered MERFISH data

# %%
# SNR cluster probabilities
cluster_probs = best_svm_cluster.predict_proba(X_merfish_mirror)
cluster_classes = best_svm_cluster.classes_

cluster_prob_cols = [f"p_cluster__{c}" for c in cluster_classes]

cluster_prob_df = pd.DataFrame(
    cluster_probs,
    columns=cluster_prob_cols,
    index=cell_metadata.index
)

# Predicted cluster and uncertainty summaries
top_two = np.sort(cluster_probs, axis=1)[:, -2:]

analysis_df = pd.concat([cell_metadata, X_merfish_mirror.add_prefix("mirror_"), cluster_prob_df], axis=1)

analysis_df["pred_cluster"] = cluster_classes[np.argmax(cluster_probs, axis=1)]
analysis_df["p_cluster_max"] = cluster_probs.max(axis=1)
analysis_df["cluster_margin"] = top_two[:, 1] - top_two[:, 0]
analysis_df["cluster_entropy"] = entropy(cluster_probs.T) / np.log(cluster_probs.shape[1])

analysis_df.head()
analysis_df.columns
analysis_df.shape
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (2925, 23)

# %% [markdown]
# # Create distributions

# %%
df_st = analysis_df[
    analysis_df["supertype"].isin(supertype_filter)
].copy()

if isinstance(df_st["supertype"].dtype, pd.CategoricalDtype):
    df_st["supertype"] = df_st["supertype"].cat.remove_unused_categories()

df_st["pred_cluster"] = pd.Categorical(
    df_st["pred_cluster"],
    categories=cluster_order,
    ordered=True
)

hard_profile = pd.crosstab(
    df_st["supertype"],
    df_st["pred_cluster"],
    normalize="index",
    dropna=False
)

# Clean column names for display
profile_display = hard_profile.copy()
profile_display.columns = [c.replace("p_cluster__", "") for c in profile_display.columns]

# Reorder columns into desired cluster order
profile_display = profile_display.reindex(columns=cluster_order)

plt.figure(figsize=(12, 5))
sns.heatmap(hard_profile, annot=True, fmt=".2f", cmap="viridis")
plt.title("Hard label predicted SNR-cluster profile by MERFISH supertype")
plt.xlabel("Predicted SNR projection cluster")
plt.ylabel("MERFISH supertype")
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig(
    "Figures/fig_13_hard_labels.png",
    bbox_inches="tight",
    facecolor="white"
)
plt.show()




hard_profile
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x500 with 2 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# pred_cluster                 short_HIP_SUB^RSP~very_medial  \
# supertype
# 0007 L5/6 IT TPE-ENT Glut_1                       0.001340
# 0008 L5/6 IT TPE-ENT Glut_2                       0.068129
# 0010 L5/6 IT TPE-ENT Glut_4                       0.025063
# 0129 NP PPP Glut_1                                0.267241
#
# pred_cluster                 med_short_RSP_VIS^RSP~very_medial  \
# supertype
# 0007 L5/6 IT TPE-ENT Glut_1                           0.000000
# 0008 L5/6 IT TPE-ENT Glut_2                           0.098152
# 0010 L5/6 IT TPE-ENT Glut_4                           0.081871
# 0129 NP PPP Glut_1                                    0.353448
#
# pred_cluster                 med_xlong_RSP_VIS_STR^blend~medial  \
# supertype
# 0007 L5/6 IT TPE-ENT Glut_1                            0.045576
# 0008 L5/6 IT TPE-ENT Glut_2                            0.211316
# 0010 L5/6 IT TPE-ENT Glut_4                            0.167084
# 0129 NP PPP Glut_1                                     0.163793
#
# pred_cluster                 med_AMY_STRv_STRd^ORB~very_lateral  \
# supertype
# 0007 L5/6 IT TPE-ENT Glut_1                            0.270777
# 0008 L5/6 IT TPE-ENT Glut_2                            0.518476
# 0010 L5/6 IT TPE-ENT Glut_4                            0.695071
# 0129 NP PPP Glut_1                                     0.155172
#
# pred_cluster                 long_xlong_STRd_STRv_AI^ORB~very_lateral  \
# supertype
# 0007 L5/6 IT TPE-ENT Glut_1                                  0.679625
# 0008 L5/6 IT TPE-ENT Glut_2                                  0.087760
# 0010 L5/6 IT TPE-ENT Glut_4                                  0.014202
# 0129 NP PPP Glut_1                                           0.000000
#
# pred_cluster                 med_RSP_VIS_TEa^blend~medial  \
# supertype
# 0007 L5/6 IT TPE-ENT Glut_1                      0.000000
# 0008 L5/6 IT TPE-ENT Glut_2                      0.005774
# 0010 L5/6 IT TPE-ENT Glut_4                      0.013367
# 0129 NP PPP Glut_1                               0.043103
#
# pred_cluster                 xshort_mixed^none~medial
# supertype
# 0007 L5/6 IT TPE-ENT Glut_1                  0.002681
# 0008 L5/6 IT TPE-ENT Glut_2                  0.010393
# 0010 L5/6 IT TPE-ENT Glut_4                  0.003342
# 0129 NP PPP Glut_1                           0.017241

# %%
## Chi squared test for independene:

# %%
# Raw observed counts: this is what the chi-squared test needs
observed = pd.crosstab(
    df_st["supertype"],
    df_st["pred_cluster"],
    dropna=False
)

# Keep your preferred cluster order
observed = observed.reindex(columns=cluster_order, fill_value=0)

# Optional: remove empty rows/columns if any exist
observed = observed.loc[
    observed.sum(axis=1) > 0,
    observed.sum(axis=0) > 0
]

observed

chi2, p, dof, expected = chi2_contingency(
    observed,
    correction=False
)

expected = pd.DataFrame(
    expected,
    index=observed.index,
    columns=observed.columns
)

print(f"Chi-squared statistic = {chi2:.3f}")
print(f"Degrees of freedom = {dof}")
print(f"p-value = {p:.18e}")
# Out:
# Chi-squared statistic = 1791.357
# Degrees of freedom = 18
# p-value = 0.000000000000000000e+00

# %%
df_st = analysis_df[
    analysis_df["supertype"].isin(supertype_filter)
].copy()

# Remove unused categories if supertype is categorical
if isinstance(df_st["supertype"].dtype, pd.CategoricalDtype):
    df_st["supertype"] = df_st["supertype"].cat.remove_unused_categories()

profile = (
    df_st
    .groupby("supertype")[cluster_prob_cols]
    .mean()
)

# Clean column names for display
profile_display = profile.copy()
profile_display.columns = [c.replace("p_cluster__", "") for c in profile_display.columns]

# Reorder columns into desired cluster order
profile_display = profile_display.reindex(columns=cluster_order)

plt.figure(figsize=(12, 5))
sns.heatmap(profile_display, annot=True, fmt=".2f", cmap="viridis")
plt.title("Soft label predicted SNR-cluster probability profile by MERFISH supertype")
plt.xlabel("Predicted SNR projection cluster")
plt.ylabel("MERFISH supertype")
plt.tight_layout()
plt.savefig(
    "Figures/fig_14_soft_labels.png",
    bbox_inches="tight",
    facecolor="white"
)
plt.show()
# Out:
# /var/folders/c7/ytg8ypcn5cn63c0pfbjpj5yc0000gp/T/ipykernel_13188/3651459415.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("supertype")[cluster_prob_cols]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x500 with 2 Axes>

# %%
long_probs = df_st.melt(
    id_vars=[
        "supertype", "pred_cluster", "p_cluster_max",
        "cluster_entropy", "substructure", "structure"
    ],
    value_vars=cluster_prob_cols,
    var_name="cluster",
    value_name="probability"
)

# Clean probability column names so they match cluster_order
long_probs["cluster"] = long_probs["cluster"].str.replace("p_cluster__", "", regex=False)

plt.figure(figsize=(14, 7))

sns.boxplot(
    data=long_probs,
    x="cluster",
    y="probability",
    hue="supertype",
    order=cluster_order
)

plt.xticks(rotation=90)
plt.title("Distribution of predicted SNR-cluster probabilities by supertype")
plt.xlabel("SNR projection cluster")
plt.ylabel("Predicted probability")
plt.legend(title="Supertype", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.tight_layout()
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1400x700 with 1 Axes>

# %%
g = sns.FacetGrid(
    long_probs,
    col="cluster",
    col_order=cluster_order,
    col_wrap=3,
    sharey=True,
    height=4
)

g.map_dataframe(
    sns.boxplot,
    x="supertype",
    y="probability"
)

for ax in g.axes.flatten():
    ax.tick_params(axis="x", rotation=90)

g.set_titles("{col_name}")
g.set_axis_labels("Supertype", "Predicted probability")
plt.tight_layout()
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1200x1200 with 7 Axes>

# %% [markdown]
# ## Using supertype classifier probabilities

# %%
cluster_prob_cols = [f"cluster_prob_{c}" for c in cluster_names]
supertype_prob_cols = [f"supertype_prob_{s}" for s in supertype_names]

cluster_probs = cell_metadata[cluster_prob_cols].to_numpy()
supertype_probs = cell_metadata[supertype_prob_cols].to_numpy()

cluster_supertype_soft = cluster_probs.T @ supertype_probs

cluster_supertype_soft = pd.DataFrame(
    cluster_supertype_soft,
    index=cluster_names,
    columns=supertype_names
)

cluster_supertype_soft_norm = cluster_supertype_soft.div(
    cluster_supertype_soft.sum(axis=1),
    axis=0
)

cluster_supertype_soft_norm
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                             0007 L5/6 IT TPE-ENT Glut_1  \
# med_long_RSP_VIS^RSP_mixed                     0.277360
# med_long_STRv_STRd^ORB                         0.289578
# med_xshort_^mixed                              0.282329
# short_HIP_strong_SUB^RSP                       0.210044
# short_med_long_RSP_VIS^RSP                     0.193377
#
#                             0008 L5/6 IT TPE-ENT Glut_2  \
# med_long_RSP_VIS^RSP_mixed                     0.285267
# med_long_STRv_STRd^ORB                         0.290431
# med_xshort_^mixed                              0.277506
# short_HIP_strong_SUB^RSP                       0.278755
# short_med_long_RSP_VIS^RSP                     0.286991
#
#                             0010 L5/6 IT TPE-ENT Glut_4  0129 NP PPP Glut_1
# med_long_RSP_VIS^RSP_mixed                     0.334782            0.102591
# med_long_STRv_STRd^ORB                         0.373630            0.046361
# med_xshort_^mixed                              0.359085            0.081080
# short_HIP_strong_SUB^RSP                       0.272021            0.239180
# short_med_long_RSP_VIS^RSP                     0.347277            0.172354

# %%
cluster_supertype_soft = supertype_probs.T @ cluster_probs

cluster_supertype_soft = pd.DataFrame(
    cluster_supertype_soft,
    index=supertype_names,
    columns=cluster_names
)

cluster_supertype_soft_norm = cluster_supertype_soft.div(
    cluster_supertype_soft.sum(axis=1),
    axis=0
)

cluster_supertype_soft_norm
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              med_long_RSP_VIS^RSP_mixed  \
# 0007 L5/6 IT TPE-ENT Glut_1                    0.196635
# 0008 L5/6 IT TPE-ENT Glut_2                    0.190138
# 0010 L5/6 IT TPE-ENT Glut_4                    0.181430
# 0129 NP PPP Glut_1                             0.195885
#
#                              med_long_STRv_STRd^ORB  med_xshort_^mixed  \
# 0007 L5/6 IT TPE-ENT Glut_1                0.338630           0.311712
# 0008 L5/6 IT TPE-ENT Glut_2                0.319301           0.288050
# 0010 L5/6 IT TPE-ENT Glut_4                0.333987           0.303055
# 0129 NP PPP Glut_1                         0.146012           0.241094
#
#                              short_HIP_strong_SUB^RSP  \
# 0007 L5/6 IT TPE-ENT Glut_1                  0.074553
# 0008 L5/6 IT TPE-ENT Glut_2                  0.093020
# 0010 L5/6 IT TPE-ENT Glut_4                  0.073805
# 0129 NP PPP Glut_1                           0.228643
#
#                              short_med_long_RSP_VIS^RSP
# 0007 L5/6 IT TPE-ENT Glut_1                    0.078471
# 0008 L5/6 IT TPE-ENT Glut_2                    0.109490
# 0010 L5/6 IT TPE-ENT Glut_4                    0.107723
# 0129 NP PPP Glut_1                             0.188367

# %% [markdown]
# ## Using MERFISH Supertype assignment

# %%
supertype_onehot = pd.get_dummies(cell_metadata["supertype"])

cluster_supertype_assigned = cluster_probs.T @ supertype_onehot.to_numpy()

cluster_supertype_assigned = pd.DataFrame(
    cluster_supertype_assigned,
    index=cluster_names,
    columns=supertype_onehot.columns
)

cluster_supertype_assigned_norm = cluster_supertype_assigned.div(
    cluster_supertype_assigned.sum(axis=1),
    axis=0
)

cluster_supertype_assigned_norm
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                             0001 CLA-EPd-CTX Car3 Glut_1  \
# med_long_RSP_VIS^RSP_mixed                      0.001106
# med_long_STRv_STRd^ORB                          0.002465
# med_xshort_^mixed                               0.001167
# short_HIP_strong_SUB^RSP                        0.000849
# short_med_long_RSP_VIS^RSP                      0.000708
#
#                             0002 CLA-EPd-CTX Car3 Glut_2  \
# med_long_RSP_VIS^RSP_mixed                      0.000087
# med_long_STRv_STRd^ORB                          0.000151
# med_xshort_^mixed                               0.000091
# short_HIP_strong_SUB^RSP                        0.000066
# short_med_long_RSP_VIS^RSP                      0.000058
#
#                             0003 IT EP-CLA Glut_1  0004 IT EP-CLA Glut_2  \
# med_long_RSP_VIS^RSP_mixed               0.001204               0.003736
# med_long_STRv_STRd^ORB                   0.003117               0.010716
# med_xshort_^mixed                        0.000984               0.003369
# short_HIP_strong_SUB^RSP                 0.000716               0.002673
# short_med_long_RSP_VIS^RSP               0.000599               0.002128
#
#                             0007 L5/6 IT TPE-ENT Glut_1  \
# med_long_RSP_VIS^RSP_mixed                     0.011337
# med_long_STRv_STRd^ORB                         0.026649
# med_xshort_^mixed                              0.011961
# short_HIP_strong_SUB^RSP                       0.007050
# short_med_long_RSP_VIS^RSP                     0.006237
#
#                             0008 L5/6 IT TPE-ENT Glut_2  \
# med_long_RSP_VIS^RSP_mixed                     0.017296
# med_long_STRv_STRd^ORB                         0.021689
# med_xshort_^mixed                              0.016952
# short_HIP_strong_SUB^RSP                       0.011463
# short_med_long_RSP_VIS^RSP                     0.015447
#
#                             0010 L5/6 IT TPE-ENT Glut_4  \
# med_long_RSP_VIS^RSP_mixed                     0.020424
# med_long_STRv_STRd^ORB                         0.033238
# med_xshort_^mixed                              0.024990
# short_HIP_strong_SUB^RSP                       0.010159
# short_med_long_RSP_VIS^RSP                     0.018776
#
#                             0011 L5/6 IT TPE-ENT Glut_5  \
# med_long_RSP_VIS^RSP_mixed                     0.000040
# med_long_STRv_STRd^ORB                         0.000040
# med_xshort_^mixed                              0.000022
# short_HIP_strong_SUB^RSP                       0.000136
# short_med_long_RSP_VIS^RSP                     0.000015
#
#                             0012 L5/6 IT TPE-ENT Glut_6  \
# med_long_RSP_VIS^RSP_mixed                     0.000025
# med_long_STRv_STRd^ORB                         0.000004
# med_xshort_^mixed                              0.000019
# short_HIP_strong_SUB^RSP                       0.000005
# short_med_long_RSP_VIS^RSP                     0.000078
#
#                             0013 L6 IT CTX Glut_1  ...  \
# med_long_RSP_VIS^RSP_mixed               0.000234  ...
# med_long_STRv_STRd^ORB                   0.000035  ...
# med_xshort_^mixed                        0.000149  ...
# short_HIP_strong_SUB^RSP                 0.000138  ...
# short_med_long_RSP_VIS^RSP               0.000483  ...
#
#                             0264 OT D3 Folh1 Gaba_3  \
# med_long_RSP_VIS^RSP_mixed                 0.000021
# med_long_STRv_STRd^ORB                     0.000010
# med_xshort_^mixed                          0.000034
# short_HIP_strong_SUB^RSP                   0.000018
# short_med_long_RSP_VIS^RSP                 0.000017
#
#                             0285 STR-PAL Chst9 Gaba_1  0290 IA Mgp Gaba_1  \
# med_long_RSP_VIS^RSP_mixed                   0.000036            0.000014
# med_long_STRv_STRd^ORB                       0.000081            0.000017
# med_xshort_^mixed                            0.000020            0.000033
# short_HIP_strong_SUB^RSP                     0.000018            0.000014
# short_med_long_RSP_VIS^RSP                   0.000014            0.000013
#
#                             0291 IA Mgp Gaba_2  \
# med_long_RSP_VIS^RSP_mixed            0.000027
# med_long_STRv_STRd^ORB                0.000062
# med_xshort_^mixed                     0.000042
# short_HIP_strong_SUB^RSP              0.000022
# short_med_long_RSP_VIS^RSP            0.000019
#
#                             0355 MEA-BST Lhx6 Nr2e1 Gaba_2  \
# med_long_RSP_VIS^RSP_mixed                        0.000089
# med_long_STRv_STRd^ORB                            0.000129
# med_xshort_^mixed                                 0.000109
# short_HIP_strong_SUB^RSP                          0.000071
# short_med_long_RSP_VIS^RSP                        0.000062
#
#                             0356 MEA-BST Lhx6 Nr2e1 Gaba_3  \
# med_long_RSP_VIS^RSP_mixed                        0.000015
# med_long_STRv_STRd^ORB                            0.000034
# med_xshort_^mixed                                 0.000018
# short_HIP_strong_SUB^RSP                          0.000011
# short_med_long_RSP_VIS^RSP                        0.000009
#
#                             0380 CEA-AAA-BST Six3 Sp9 Gaba_8  \
# med_long_RSP_VIS^RSP_mixed                          0.000021
# med_long_STRv_STRd^ORB                              0.000022
# med_xshort_^mixed                                   0.000022
# short_HIP_strong_SUB^RSP                            0.000016
# short_med_long_RSP_VIS^RSP                          0.000015
#
#                             0510 COAa-PAA-MEA Barhl2 Glut_2  \
# med_long_RSP_VIS^RSP_mixed                         0.000020
# med_long_STRv_STRd^ORB                             0.000022
# med_xshort_^mixed                                  0.000022
# short_HIP_strong_SUB^RSP                           0.000016
# short_med_long_RSP_VIS^RSP                         0.000015
#
#                             0512 COAa-PAA-MEA Barhl2 Glut_4  \
# med_long_RSP_VIS^RSP_mixed                         0.000310
# med_long_STRv_STRd^ORB                             0.000820
# med_xshort_^mixed                                  0.000329
# short_HIP_strong_SUB^RSP                           0.000222
# short_med_long_RSP_VIS^RSP                         0.000181
#
#                             0514 COAa-PAA-MEA Barhl2 Glut_6
# med_long_RSP_VIS^RSP_mixed                         0.000686
# med_long_STRv_STRd^ORB                             0.001059
# med_xshort_^mixed                                  0.000885
# short_HIP_strong_SUB^RSP                           0.000528
# short_med_long_RSP_VIS^RSP                         0.000469
#
# [5 rows x 167 columns]

# %%
# Use GMM to create soft labels for the SNR neurons based on their projections
gmm_pipe_7 = make_pipeline(
                ColumnTransformer(
                    [("log",
                      make_pipeline(
                          FunctionTransformer(np.log1p),
                          StandardScaler()
                      ),
                      length_cols)]
                ),
                GaussianMixture(
                    n_components=7,
                    covariance_type='spherical',
                    init_params='k-means++',
                    n_init=10,
                    random_state = 24601
                )
            )

gmm_7_labs = gmm_pipe_7.fit_predict(ec_snr_data)

# Save these soft labels
cluster_probs_snr = gmm_pipe_7.predict_proba(ec_snr_data)

# Now get soft MERFISH supertype probabilities for the SNR neuron locations
coord_cols = ["x", "y", "z"]

supertype_probs_snr = best_svm_supertype.predict_proba(
    ec_snr_data[coord_cols]
)

print(ec_snr_data.columns)

# 3. Soft expected cluster-supertype counts
cluster_supertype_soft = cluster_probs_snr.T @ supertype_probs_snr



cluster_supertype_soft = pd.DataFrame(
    cluster_supertype_soft,
    index=cluster_names,
    columns=merfish_supertype_clf.classes_
)
# Out:
# Index(['mouseID', 'neuronNR', 'neuron_ID', 'FRP_endpoint', 'FRP_length',
#        'SS_endpoint', 'SS_length', 'VIS_endpoint', 'VIS_length',
#        'VISpor_endpoint', 'VISpor_length', 'RSP_endpoint', 'RSP_length',
#        'PTLp_endpoint', 'PTLp_length', 'ORB_endpoint', 'ORB_length',
#        'MO_endpoint', 'MO_length', 'AUD_endpoint', 'AUD_length',
#        'ACA_endpoint', 'ACA_length', 'PL_endpoint', 'PL_length',
#        'ILA_endpoint', 'ILA_length', 'VISC_endpoint', 'VISC_length',
#        'AI_endpoint', 'AI_length', 'GU_endpoint', 'GU_length', 'TEa_endpoint',
#        'TEa_length', 'PERI_endpoint', 'PERI_length', 'ECT_endpoint',
#        'ECT_length', 'OLF_endpoint', 'OLF_length', 'PAR_endpoint',
#        'PAR_length', 'POST_endpoint', 'POST_length', 'PRE_endpoint',
#        'PRE_length', 'SUB_endpoint', 'SUB_length', 'HIP_endpoint',
#        'HIP_length', 'CLA_endpoint', 'CLA_length', 'EP_endpoint', 'EP_length',
#        'AMY_endpoint', 'AMY_length', 'STRd_endpoint', 'STRd_length',
#        'STRv_endpoint', 'STRv_length', 'x', 'y', 'z', 'comment', 'injection',
#        'proj', 'count', 'label_names', 'labels'],
#       dtype='object')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 41
#      37
#      38
#      39 cluster_supertype_soft = pd.DataFrame(
#      40     cluster_supertype_soft,
# ---> 41     index=cluster_names,
#      42     columns=merfish_supertype_clf.classes_
#      43 )
#
# NameError: name 'cluster_names' is not defined
